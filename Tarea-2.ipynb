# %% [markdown]
# # PROGRAMA DE CIENCIAS DE LOS DATOS
# ## **CURSO: APRENDIZAJE AUTOMÁTICO (MACHINE LEARNING)**
# ### **TAREA 2**
#
# Profesor: MSc. Felipe Meza
#
# Alumnos:
#
#   Lester Salazar Viales
#
#   Randal Salazar Viales

# %% [markdown]
# # Tutorial Pandas
# ## **Creación ambiente**
#
# **1)** Instalar la el aplicativo Miniconda, el cual puede ser descargado de la siguiente ruta:
#
# https://conda.io/miniconda.html,
#
# **2)** Una vez instalado el aplicativo, se procede a crear el ambiente de trabajo utilizando el siguiente comando
#
#        conda create --name "nombre del ambiente" python=3
#
#        En donde dice python se debe de especificar la versión de python que se va a utilizar en nuestro caso es 3
#
#        Tal como se muestra en la siguiente imagen
#
#  ![creacion%20ambiente.jpg](attachment:creacion%20ambiente.jpg)
#
#  **3)** Una vez creado el ambiente se procede a verificar si el mismo fue creado utilizando el siguiente comando:
#
#         conda env list
#
#         Lo que nos mostrará algo similar a la siguiente imagen
#
#  ![listado%20de%20ambientes.jpg](attachment:listado%20de%20ambientes.jpg)
#
#  **4)** Ya con el ambiente creado se procede a activarlo utilizando el siguiente comando
#
#        conda activate Tarea-2
#
#        Lo que nos da como resultado algo parecido a lo que se muestra en al siguiente imagen
#
# ![activacion%20de%20ambiente.jpg](attachment:activacion%20de%20ambiente.jpg)
#
# **5)** Con el ambiente activo se procede a instalar los paquetes que se van a utlizar, para lo cual
#        utlizamos el siguiente comando
#
#        conda install numpy matplotlib pandas scikit-learn jupyter notebook
#
#        Lo que nos mostrará algo similar a las siguientes imagenes
#
# ![instalacion%20de%20paquetes.jpg](attachment:instalacion%20de%20paquetes.jpg)
# ![instalacion%20de%20paquetes2.jpg](attachment:instalacion%20de%20paquetes2.jpg)
# ![instalacion%20de%20paquetes3.jpg](attachment:instalacion%20de%20paquetes3.jpg)
# ![instalacion%20de%20paquetes4.jpg](attachment:instalacion%20de%20paquetes4.jpg)
#
# **6)** Una vez instalados los paquetes se procede a verificar que se hayan instalado utilizando el siguiente comando
#
#        conda list
#
#        Lo que nos mostraría algo similar a la siguiente imagen
#
#
#
# **7)** Una vez creado el ambiente e instalados los paquetes procedemos a inicar el notebook utilizadon el siguiente comando
#
#        jupyter notebook
#
#        Lo que nos levantará el web browser que tenemos por defecto y la pagina principal de Jupyter, tal como se
#        muestra en la siguiente imagen
#
#  ![notebook.JPG](attachment:notebook.JPG)
#
#
# ## **Creación de Notebook**
#
# Una vez dentro de la pagina principal se procederá a crear la notebook en la cual se va a trabajar. Para crear la notebook se procede a presionar el botón que dice "New" y se selecciona python 3 para que se cree una notebook para python que es donde vamos a ejcutar Pandas
#
# ![creacion%20notebook.jpg](attachment:creacion%20notebook.jpg)
#
# Realizado el punto anterior se nos habilitará una nueva pestaña en el navegador muy similar a la que se muestra en la siguiente imagen
#
# ![notebook1.JPG](attachment:notebook1.JPG)
#
# ## **Importar Librerias a utilizar**
#
# Con nuestra notebook creada y funcional procederemos a importar las librerias de trabaja que vamos a utilizar, dentro de las cuales se encuentra Pandas que es la protagonista de este tutorial, tal como se muestra en la siguiente imagen se debe de incluir el codigo que se muetra en ella y luego presionar el boton de ejcutar.
#
# ![librerias.JPG](attachment:librerias.JPG)
#
# ## **Tipos de datos en Pandas**
#
# Pandas puede utilizar varios tipos, los que mas se utilizan son los que se muestran en la siguiente imagen.
#
# ![pandas%20tipos%20de%20datos.JPG](attachment:pandas%20tipos%20de%20datos.JPG)
#
#
# **int y float**: estos datos serían numéricos, los primeros, como su nombre lo indican serían números enteros mientras que los float o flotantes, serían datos con decimales.
#
# **object**: funciona de forma similar a la cadena de datos en Python.
#
# **datetime**: que vendría siendo algo así como día y hora, es un tipo de datos muy útil para manejar series temporales de datos.
#
# **DataFrame**: es un tipo de dato que permite almacenar y manipular datos tabulados en filas y columnas.
#
# ![dataframe.JPG](attachment:dataframe.JPG)
#
#
# ## **Trabajando con DataFrames**
#
# ### **Creacion de Dataframes utilizando una tabla**
#
# Para crar un DataFrame lo que vamos a realizar primero es crear una lista para luego crear el dataFrame con base a dicha estructura de datos. Ver imagen adjunta del codigo.
#
# ![pandas1.JPG](attachment:pandas1.JPG)
#
# Como podemos notar se crea una variable llamada tabla a la cual se le asignan valores representados en una matriz, dicha tabla se carga en el dataframe y luego se imprimen los valores por pantalla.
#
# ### **Trabajando con valores nulos**
#
# En los dataframes de pandas tenemos una función que devuelve que nos indica si uno de los campos tiene valores nulos. La funcion es isnull.
# Para ver el funcionamiento vamos a realizar el siguiente ejemplo
#
# ![pandas2.JPG](attachment:pandas2.JPG)
#
# Ahora utilizamos el siguiente codigo para que nos indique cuales son los valures nulos, dichos valores van a estar representados por un True.
#
# ![pandas3.JPG](attachment:pandas3.JPG)
#
# Como pueden notar devuelve una matriz en donde los valores nulos son indicador con True
#
# ### **Cargando valores desde un archivo csv con pandas**

# %%
print(df)
# Out:
#                                                    city state country  \
# datetime
# 10/10/1949 20:30                             san marcos    tx      us
# 10/10/1949 21:00                           lackland afb    tx     NaN
# 10/10/1955 17:00                   chester (uk/england)   NaN      gb
# 10/10/1956 21:00                                   edna    tx      us
# 10/10/1960 20:00                                kaneohe    hi      us
# 10/10/1961 19:00                                bristol    tn      us
# 10/10/1965 21:00                     penarth (uk/wales)   NaN      gb
# 10/10/1965 23:45                                norwalk    ct      us
# 10/10/1966 20:00                              pell city    al      us
# 10/10/1966 21:00                               live oak    fl      us
# 10/10/1968 13:00                              hawthorne    ca      us
# 10/10/1968 19:00                                brevard    nc      us
# ...
